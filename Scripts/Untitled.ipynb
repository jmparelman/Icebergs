# %%
import pandas as pd
import os,glob,sys
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# get data file names
files = glob.glob('../stats/*.csv')

# %%
DataList = []
for f in files:
    data_in = pd.read_csv(f)
    data_in['BergID'] = f.split('/')[-1][:-4]
    DataList.append(data_in)
    
Data = pd.concat(DataList,ignore_index=True)

# %%
# plot data
fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
Data.groupby('BergID').plot(x='date',y='size')
# Out:
# /Users/jake/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.py:537: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# BergID
# a23a      AxesSubplot(0.125,0.125;0.775x0.755)
# a56       AxesSubplot(0.125,0.125;0.775x0.755)
# a57       AxesSubplot(0.125,0.125;0.775x0.755)
# a57a      AxesSubplot(0.125,0.125;0.775x0.755)
# a57b      AxesSubplot(0.125,0.125;0.775x0.755)
# a61       AxesSubplot(0.125,0.125;0.775x0.755)
# a62       AxesSubplot(0.125,0.125;0.775x0.755)
# a62a      AxesSubplot(0.125,0.125;0.775x0.755)
# a63       AxesSubplot(0.125,0.125;0.775x0.755)
# a64       AxesSubplot(0.125,0.125;0.775x0.755)
# a65       AxesSubplot(0.125,0.125;0.775x0.755)
# a66       AxesSubplot(0.125,0.125;0.775x0.755)
# a67       AxesSubplot(0.125,0.125;0.775x0.755)
# a68       AxesSubplot(0.125,0.125;0.775x0.755)
# a68a      AxesSubplot(0.125,0.125;0.775x0.755)
# a68b      AxesSubplot(0.125,0.125;0.775x0.755)
# b09b      AxesSubplot(0.125,0.125;0.775x0.755)
# b09c      AxesSubplot(0.125,0.125;0.775x0.755)
# b09d      AxesSubplot(0.125,0.125;0.775x0.755)
# b09f      AxesSubplot(0.125,0.125;0.775x0.755)
# b09g      AxesSubplot(0.125,0.125;0.775x0.755)
# b09h      AxesSubplot(0.125,0.125;0.775x0.755)
# b09i      AxesSubplot(0.125,0.125;0.775x0.755)
# b09j      AxesSubplot(0.125,0.125;0.775x0.755)
# b15aa     AxesSubplot(0.125,0.125;0.775x0.755)
# b15ab     AxesSubplot(0.125,0.125;0.775x0.755)
# b15ac     AxesSubplot(0.125,0.125;0.775x0.755)
# b15b      AxesSubplot(0.125,0.125;0.775x0.755)
# b15f      AxesSubplot(0.125,0.125;0.775x0.755)
# b15g      AxesSubplot(0.125,0.125;0.775x0.755)
#                           ...
# d20b      AxesSubplot(0.125,0.125;0.775x0.755)
# d21a      AxesSubplot(0.125,0.125;0.775x0.755)
# d21b      AxesSubplot(0.125,0.125;0.775x0.755)
# d22       AxesSubplot(0.125,0.125;0.775x0.755)
# d23       AxesSubplot(0.125,0.125;0.775x0.755)
# d24       AxesSubplot(0.125,0.125;0.775x0.755)
# d25       AxesSubplot(0.125,0.125;0.775x0.755)
# d26       AxesSubplot(0.125,0.125;0.775x0.755)
# d27       AxesSubplot(0.125,0.125;0.775x0.755)
# uk052     AxesSubplot(0.125,0.125;0.775x0.755)
# uk093     AxesSubplot(0.125,0.125;0.775x0.755)
# uk130     AxesSubplot(0.125,0.125;0.775x0.755)
# uk174     AxesSubplot(0.125,0.125;0.775x0.755)
# uk192     AxesSubplot(0.125,0.125;0.775x0.755)
# uk235     AxesSubplot(0.125,0.125;0.775x0.755)
# uk290     AxesSubplot(0.125,0.125;0.775x0.755)
# uk304     AxesSubplot(0.125,0.125;0.775x0.755)
# uk314     AxesSubplot(0.125,0.125;0.775x0.755)
# uk315     AxesSubplot(0.125,0.125;0.775x0.755)
# uk316     AxesSubplot(0.125,0.125;0.775x0.755)
# uk318     AxesSubplot(0.125,0.125;0.775x0.755)
# uk319     AxesSubplot(0.125,0.125;0.775x0.755)
# uk320     AxesSubplot(0.125,0.125;0.775x0.755)
# uk321     AxesSubplot(0.125,0.125;0.775x0.755)
# uk321b    AxesSubplot(0.125,0.125;0.775x0.755)
# uk322     AxesSubplot(0.125,0.125;0.775x0.755)
# uk323     AxesSubplot(0.125,0.125;0.775x0.755)
# uk324     AxesSubplot(0.125,0.125;0.775x0.755)
# uk325     AxesSubplot(0.125,0.125;0.775x0.755)
# uk326     AxesSubplot(0.125,0.125;0.775x0.755)
# Length: 117, dtype: object
